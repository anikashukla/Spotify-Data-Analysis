# %% [markdown]
# <a href="https://colab.research.google.com/github/anikashukla/Spotify-Data-Analysis/blob/main/spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SPOTIFY DATA ANALYSIS**

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks = pd.read_csv('tracks.csv')
df_tracks.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,1,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve         6.0
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista         0.0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado         0.0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado         0.0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening         0.0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0     126903.0       0.0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1      98200.0       0.0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2     181640.0       0.0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3     176907.0       0.0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4     163080.0       0.0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   22-02-1922         0.645  0.4450  0.0   -13.338   1.0       0.4510
# 1   01-06-1922         0.695  0.2630  0.0   -22.136   1.0       0.9570
# 2   21-03-1922         0.434  0.1770  1.0   -21.180   1.0       0.0512
# 3   21-03-1922         0.321  0.0946  7.0   -27.961   1.0       0.0504
# 4         1922         0.402  0.1580  3.0   -16.900   0.0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851             3.0
# 1         0.797            0.0000     0.148    0.655  102.009             1.0
# 2         0.994            0.0218     0.212    0.457  130.418             5.0
# 3         0.995            0.9180     0.104    0.397  169.980             3.0
# 4         0.989            0.1300     0.311    0.196  103.220             4.0

# %%
pd.isnull(df_tracks).sum()
# Out:
# id                  329250
# name                329251
# popularity          329250
# duration_ms         329250
# explicit            329250
# artists             329250
# id_artists          329250
# release_date        329250
# danceability        329250
# energy              329250
# key                 329250
# loudness            329250
# mode                329250
# speechiness         329250
# acousticness        329250
# instrumentalness    329250
# liveness            329250
# valence             329250
# tempo               329250
# time_signature      329250
# dtype: int64

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                257422 non-null  object
#  1   name              257421 non-null  object
#  2   popularity        257422 non-null  float64
#  3   duration_ms       257422 non-null  float64
#  4   explicit          257422 non-null  float64
#  5   artists           257422 non-null  object
#  6   id_artists        257422 non-null  object
#  7   release_date      257422 non-null  object
#  8   danceability      257422 non-null  float64
#  9   energy            257422 non-null  float64
#  10  key               257422 non-null  float64
#  11  loudness          257422 non-null  float64
#  12  mode              257422 non-null  float64
#  13  speechiness       257422 non-null  float64
#  14  acousticness      257422 non-null  float64
#  15  instrumentalness  257422 non-null  float64
#  16  liveness          257422 non-null  float64
#  17  valence           257422 non-null  float64
#  18  tempo             257422 non-null  float64
#  19  time_signature    257422 non-null  float64
# dtypes: float64(15), object(5)
# memory usage: 89.5+ MB

# %% [markdown]
# # FIND TEN LEAST POPULAR SONGS

# %%
sorted_df = df_tracks.sort_values('popularity',ascending = True).head(10)
sorted_df
# Out:
#                             id  \
# 73449   558D3GX2TjNixp21ZCjTvN
# 122958  62OPfkP8PmdhTgdPtUd5ii
# 122957  618iduhpFPYOQjWsjv8P0M
# 122956  60fP7SBdOt171LfGfT47H7
# 122955  607vA9SCLU3YucULQ3lvcp
# 122954  5z6fVw0ROXh6dFoW91PHuY
# 122953  5z4O4iHes4GkBI7VTlvhAe
# 122952  5ypy01pY6k0VO5Zjr8t1Vu
# 122951  5ymhNrzw1OpxYcna8S1w3S
# 122950  5ydL6SFmeEGkAAeh21pkes
#
#                                                      name  popularity  \
# 73449                                       THE YEAR 3000         0.0
# 122958                   Sonata pour Piano: II. Adagietto         0.0
# 122957                Nocturnes, Op. 15: No. 3 in G Minor         0.0
# 122956                                         Four Walls         0.0
# 122955                             L'Isle joyeuse, L. 106         0.0
# 122954                                       O Holy Night         0.0
# 122953  Messiah, HWV 56, Pt. 2: Thou shalt break them ...         0.0
# 122952  Préludes, Livre 1, L. 117: 1. Danseuses de Del...         0.0
# 122951                                 Portrait of Django         0.0
# 122950  Messiah, HWV 56, Pt. 2: Why do the nations so ...         0.0
#
#         duration_ms  explicit  \
# 73449      114888.0       0.0
# 122958     311453.0       0.0
# 122957     278693.0       0.0
# 122956     162520.0       0.0
# 122955     316507.0       0.0
# 122954     182555.0       0.0
# 122953     121000.0       0.0
# 122952     155013.0       0.0
# 122951     148347.0       0.0
# 122950     158067.0       0.0
#
#                                                   artists  \
# 73449                   ['The Fifth Reality', 'Benjamin']
# 122958              ['Igor Stravinsky', 'Eugene Istomin']
# 122957              ['Frédéric Chopin', 'Eugene Istomin']
# 122956                                   ['Memphis Slim']
# 122955             ['Claude Debussy', 'Robert Casadesus']
# 122954                                ['Monique Nikkole']
# 122953  ['George Frideric Handel', 'The Liverpool Phil...
# 122952             ['Claude Debussy', 'Robert Casadesus']
# 122951                              ['Michel De Villers']
# 122950  ['George Frideric Handel', 'The Liverpool Phil...
#
#                                                id_artists release_date  \
# 73449   ['5aIaavp1IwFZ3Dnehch0QD', '0GAehTZ3TTgHlTRcHJ...   10-04-2021
# 122958  ['7ie36YytMoKtPiL7tUvmoE', '0gE6uErl9csKjL0JYG...         1946
# 122957  ['7y97mc3bZRFXzT2szRM4L4', '0gE6uErl9csKjL0JYG...         1946
# 122956                         ['5JuPv0rJXe5aWNTgu8YVqZ']         1946
# 122955  ['1Uff91EOsvd99rtAupatMP', '60UJYXbYq8oGjl7FDq...         1946
# 122954                         ['6hvN3GPtJQnI6I6gKR0lgY']   19-11-1946
# 122953  ['1QL7yTHrdahRMpvNtn6rI2', '6N3Zu13wSrLNDhSkWP...         1946
# 122952  ['1Uff91EOsvd99rtAupatMP', '60UJYXbYq8oGjl7FDq...         1946
# 122951                         ['0CksgSCI7dMN2cUTzb7Wao']         1946
# 122950  ['1QL7yTHrdahRMpvNtn6rI2', '6N3Zu13wSrLNDhSkWP...         1946
#
#         danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 73449          0.616  0.8420   4.0   -14.327   0.0       0.1030        0.3570
# 122958         0.488  0.0606   5.0   -26.684   0.0       0.0397        0.9940
# 122957         0.528  0.0415   7.0   -20.088   0.0       0.0680        0.9950
# 122956         0.326  0.3410   5.0   -12.241   1.0       0.0430        0.0333
# 122955         0.284  0.1580  11.0   -17.355   0.0       0.0333        0.9920
# 122954         0.350  0.4490   8.0    -6.856   1.0       0.0273        0.7150
# 122953         0.656  0.2120   9.0   -13.687   0.0       0.0384        0.9600
# 122952         0.593  0.0207   0.0   -27.449   1.0       0.1010        0.9950
# 122951         0.343  0.1560   3.0   -15.407   1.0       0.0340        0.9830
# 122950         0.335  0.3500   7.0   -14.888   1.0       0.0377        0.9750
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 73449             0.4120    0.6730   0.7820  140.063             4.0
# 122958            0.9300    0.1230   0.1350   79.311             4.0
# 122957            0.9350    0.1540   0.1060  102.204             3.0
# 122956            0.2520    0.2380   0.1110  177.843             3.0
# 122955            0.8800    0.1010   0.0373  100.909             3.0
# 122954            0.0000    0.1690   0.1680  161.681             3.0
# 122953            0.0402    0.4960   0.4960  112.709             3.0
# 122952            0.9290    0.0825   0.1170   81.829             4.0
# 122951            0.9020    0.1040   0.1700   62.052             4.0
# 122950            0.2590    0.1710   0.5640   72.965             4.0

# %%
df_tracks.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        257422.0      27.940273      20.704777     0.0       9.0000
# duration_ms       257422.0  231307.747508  132837.083151  3344.0  172204.5000
# explicit          257422.0       0.036749       0.188145     0.0       0.0000
# danceability      257422.0       0.558008       0.169599     0.0       0.4440
# energy            257422.0       0.519153       0.258517     0.0       0.3080
# key               257422.0       5.216633       3.516117     0.0       2.0000
# loudness          257422.0     -10.703147       5.292955   -60.0     -13.5430
# mode              257422.0       0.667985       0.470937     0.0       0.0000
# speechiness       257422.0       0.096190       0.165825     0.0       0.0345
# acousticness      257422.0       0.479617       0.360707     0.0       0.1060
# instrumentalness  257422.0       0.145230       0.295714     0.0       0.0000
# liveness          257422.0       0.209121       0.180713     0.0       0.0972
# valence           257422.0       0.558594       0.263485     0.0       0.3470
# tempo             257422.0     117.888429      29.846862     0.0      95.1270
# time_signature    257422.0       3.869910       0.474955     0.0       4.0000
#
#                             50%          75%          max
# popularity            28.000000      43.0000      100.000
# duration_ms       211093.000000  263879.5000  5042185.000
# explicit               0.000000       0.0000        1.000
# danceability           0.572000       0.6840        0.988
# energy                 0.522000       0.7310        1.000
# key                    5.000000       8.0000       11.000
# loudness              -9.773000      -6.7780        5.109
# mode                   1.000000       1.0000        1.000
# speechiness            0.044300       0.0720        0.970
# acousticness           0.477000       0.8370        0.996
# instrumentalness       0.000094       0.0439        1.000
# liveness               0.136000       0.2680        1.000
# valence                0.576000       0.7840        1.000
# tempo                116.185000     135.6630      243.507
# time_signature         4.000000       4.0000        5.000

# %% [markdown]
# # TOP TEN POPULAR SONGS WITH POPULARITY > 90

# %%
most_popular = df_tracks.query('popularity>90',inplace = False).sort_values('popularity', ascending= False)
most_popular[:10]
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#        popularity  duration_ms  explicit  \
# 93802       100.0     198082.0       1.0
# 93803        99.0     242014.0       1.0
# 93804        98.0     132780.0       0.0
# 92810        97.0     215627.0       1.0
# 92811        97.0     160191.0       0.0
# 92813        96.0     200040.0       0.0
# 93805        96.0     242096.0       0.0
# 92814        95.0     164000.0       0.0
# 91866        94.0     226987.0       1.0
# 92816        94.0     198371.0       0.0
#
#                                               artists  \
# 93802    ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 93803                              ['Olivia Rodrigo']
# 93804                                 ['Masked Wolf']
# 92810                                  ['The Weeknd']
# 92811                                  ['Kali Uchis']
# 92813                                  ['The Weeknd']
# 93805  ['Bruno Mars', 'Anderson .Paak', 'Silk Sonic']
# 92814                                      ['Tiësto']
# 91866                                    ['Doja Cat']
# 92816                                      ['Giveon']
#
#                                               id_artists release_date  \
# 93802  ['1uNFoZAHBGtllmzznpCI3s', '20wkVLutqVOYrc0kxF...   19-03-2021
# 93803                         ['1McMsnEElThX1knmY4oliG']   08-01-2021
# 93804                         ['1uU7g3DNSbsu0QjSEqZtEd']   06-01-2021
# 92810                         ['1Xyo4u8uXC1ZmMpatF05PJ']   20-03-2020
# 92811                         ['1U1el3k54VvEUzo3ybLPlM']   04-12-2020
# 92813                         ['1Xyo4u8uXC1ZmMpatF05PJ']   20-03-2020
# 93805  ['0du5cEVh5yTK9QJze8zA0C', '3jK9MiCrA42lLAdMGU...   05-03-2021
# 92814                         ['2o5jDhtHVPhrJdv3cEQ99Z']   16-09-2020
# 91866                         ['5cj0lLjcoR7YOSnhnX0Po5']   07-11-2019
# 92816                         ['4fxd5Ee7UefO4CUXgwJ7IP']   27-03-2020
#
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 93802         0.677   0.696   0.0    -6.181   1.0       0.1190       0.32100
# 93803         0.585   0.436  10.0    -8.761   1.0       0.0601       0.72100
# 93804         0.778   0.695   4.0    -6.865   0.0       0.0913       0.17500
# 92810         0.680   0.826   0.0    -5.487   1.0       0.0309       0.02120
# 92811         0.653   0.524  11.0    -9.016   0.0       0.0502       0.11200
# 92813         0.514   0.730   1.0    -5.934   1.0       0.0598       0.00146
# 93805         0.586   0.616   5.0    -7.964   1.0       0.0324       0.18200
# 92814         0.798   0.620   8.0    -7.079   0.0       0.2320       0.41400
# 91866         0.749   0.463  11.0    -8.433   1.0       0.0828       0.20800
# 92816         0.449   0.465   0.0    -8.964   1.0       0.0791       0.52400
#
#        instrumentalness  liveness  valence    tempo  time_signature
# 93802          0.000000    0.4200    0.464   90.030             4.0
# 93803          0.000013    0.1050    0.132  143.874             4.0
# 93804          0.000000    0.1500    0.472  149.996             4.0
# 92810          0.000012    0.5430    0.644  118.051             4.0
# 92811          0.000000    0.2030    0.553   83.970             4.0
# 92813          0.000095    0.0897    0.334  171.005             4.0
# 93805          0.000000    0.0927    0.719  148.088             4.0
# 92814          0.019200    0.1120    0.235  120.031             4.0
# 91866          0.037100    0.3370    0.190   90.028             4.0
# 92816          0.000001    0.3030    0.543   89.087             3.0

# %% [markdown]
# # MAKE THE RELEASE DATE COLUMN AS THE INDEX COLUMN

# %%
df_tracks.set_index("release_date", inplace= True)
df_tracks.index=pd.to_datetime(df_tracks.index)
df_tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-01-06    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22           6.0     126903.0       0.0              ['Uli']
# 1922-01-06           0.0      98200.0       0.0  ['Fernando Pessoa']
# 1922-03-21           0.0     181640.0       0.0  ['Ignacio Corsini']
# 1922-03-21           0.0     176907.0       0.0  ['Ignacio Corsini']
# 1922-01-01           0.0     163080.0       0.0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# 1922-02-22    ['45tIt06XoI0Iio4LBEVpls']         0.645  0.4450  0.0   -13.338
# 1922-01-06    ['14jtPCOoNZwquk5wd9DxrY']         0.695  0.2630  0.0   -22.136
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.434  0.1770  1.0   -21.180
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.321  0.0946  7.0   -27.961
# 1922-01-01    ['3BiJGZsyX9sJchTqcSA7Su']         0.402  0.1580  3.0   -16.900
#
#               mode  speechiness  acousticness  instrumentalness  liveness  \
# release_date
# 1922-02-22     1.0       0.4510         0.674            0.7440     0.151
# 1922-01-06     1.0       0.9570         0.797            0.0000     0.148
# 1922-03-21     1.0       0.0512         0.994            0.0218     0.212
# 1922-03-21     1.0       0.0504         0.995            0.9180     0.104
# 1922-01-01     0.0       0.0390         0.989            0.1300     0.311
#
#               valence    tempo  time_signature
# release_date
# 1922-02-22      0.127  104.851             3.0
# 1922-01-06      0.655  102.009             1.0
# 1922-03-21      0.457  130.418             5.0
# 1922-03-21      0.397  169.980             3.0
# 1922-01-01      0.196  103.220             4.0

# %% [markdown]
# # FIND THE NAME OF THE ARTIST IN THE 46TH ROW OF THE DATASET

# %%
df_tracks[["artists"]].iloc[46]
# Out:
# artists    ['Grandcubby Trio']
# Name: 1922-01-01 00:00:00, dtype: object

# %% [markdown]
# # CORRELATION MAP

# %%
corr_df= df_tracks.drop(["key",'mode','explicit'],axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap = sns.heatmap(corr_df,annot=True,fmt='.1g', vmin=-1, vmax=1, center=0, cmap='flare', linewidths=1, linecolor='Black')
heatmap.set_title("Correlation Heatmap Between Variable")
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
# Out:
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'duration_ms'),
#  Text(2.5, 0, 'danceability'),
#  Text(3.5, 0, 'energy'),
#  Text(4.5, 0, 'loudness'),
#  Text(5.5, 0, 'speechiness'),
#  Text(6.5, 0, 'acousticness'),
#  Text(7.5, 0, 'instrumentalness'),
#  Text(8.5, 0, 'liveness'),
#  Text(9.5, 0, 'valence'),
#  Text(10.5, 0, 'tempo'),
#  Text(11.5, 0, 'time_signature')]

# %% [markdown]
# # SAMPLING ONLY 5 PERCENT OF THE WHOLE DATASET

# %%
sample_df = df_tracks.sample(int(0.005*len(df_tracks)))
print(len(sample_df))
# Out:
# 2933

# %% [markdown]
# # REGRESSION PLOT BETWEEN LOUDNESS AND ENERGY

# %%
plt.figure(figsize=(10,6))
sns.regplot(data = sample_df, y="loudness",x="energy", color = "c").set(title = "Loudness vs Energy Correlation")
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy Correlation')]

# %% [markdown]
# # REGRESSION PLOT BETWEEN POPULARITY AND ACOUSTICNESS

# %%
plt.figure(figsize=(10,6))
sns.regplot(data = sample_df, y="popularity",x="acousticness", color = "green").set(title = "Popularity vs Acousticness Correlation")
# Out:
# [Text(0.5, 1.0, 'Popularity vs Acousticness Correlation')]

# %% [markdown]
# # DATA ANALYSIS BASED ON THE GENRE OF SONGS

# %%
df_genre = pd.read_csv('SpotifyFeatures.csv')
df_genre.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
plt.title("Duration  vof the songs in Different Genres")
sns.color_palette("rocket", as_cmap=True)
sns.barplot(y='genre', x='duration_ms', data = df_genre)
plt.xlabel("Duration in milli seconds")
plt.ylabel("Genres")
# Out:
# Text(0, 0.5, 'Genres')

# %%
sns.set_style(style = "darkgrid")
plt.figure(figsize = (10,5))
famous = df_genre.sort_values("popularity", ascending=False).head(10)
sns.barplot(y='genre', x='popularity', data=famous).set(title = 'Top 5 genres by Popularity')
# Out:
# [Text(0.5, 1.0, 'Top 5 genres by Popularity')]
